# %%
import pandas as pd, numpy as np
from convokit import Corpus, download

# %% [markdown]
# Documentation for ConvoKit: https://convokit.cornell.edu/documentation/index.html
#
# Tutorial for using ConvoKit for reasearch: https://medium.com/nyu-ds-review/how-to-do-natural-language-processing-of-conversations-in-python-with-convokit-b95b700b8256

# %%
# Download a corpus
kanye = Corpus(filename=download("subreddit-Kanye"))

# %%
kanye.print_summary_stats()
# Out:
# Number of Speakers: 120224
# Number of Utterances: 1513193
# Number of Conversations: 176544

# %%
a = kanye.random_utterance()

# %%
a.meta["title"]
# Out:
# 'Can We Just Revel in This for A Minute'

# %%
a.print_conversation_structure()
# Out:
# squamch
#     Good_with_cows
#         squamch
#             Good_with_cows
#                 LearndAstronomer28
#                 andrew02020
#                 lliinnddsseeyy
#             9warbane
#         gottagofaster
#             NarcissisticGod
#     JayJKov
#         richtofensdad
#         KendrickMakaveli
#             Chubbsx
#                 WhatsUpMattG
#             StuntingOnAJumbotron
#     ChampagneCJ
#     MachoDagger
#         Eklein34
#             EdenH
#                 KendrickMakaveli
#                     [deleted]
#                     Eklein34
#                     Eklein34
#                         NeededKoalafications
#             MavEric01
#                 supalaser
#                     MavEric01
#                         supalaser
#     pseudomonikers8
#     [deleted]
#     chihawks
#         squamch
#             chihawks
#         IamANewRedditUser
#             chihawks
#     tastar1

# %%
a.get_utterances_dataframe().text
# Out:
# id
# 5mnczn
# dc4u6v2    Whenever I see pictures of them I get the feel...
# dc4ubue                     Kim &gt;&gt;&gt;&gt;&gt;&gt; Bee
# dc4ukns            Look at how she's looking back at him tho
# dc4ursn    alright, yeah, you're definitely not wrong. I'...
# dc4vrxf    Tbf it's Kim Kardashian. Like, she usually has...
# dc4w6cr    Kim &gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&gt;&g...
# dc52pew                                         Kim K bad af
# dc52qu0                        Yo what tats does Kanye have?
# dc53ris    https://www.bustle.com/articles/67020-how-many...
# dc58yvs    I'm sorry bro, I love Kim and Kanye but Beyonc...
# dc5966x                             Do you know which songs?
# dc59jfc    Here's what the article says, I dunno if there...
# dc5aofi    cant tell if hes staring at cleavage or not bu...
# dc5b0vm    Theres one pic where kanyes kinda look down at...
# dc5bh3e    Some people are more stoic than others. Some p...
# ...
